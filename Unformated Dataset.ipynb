# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("./dataset/SOF PUF 2023.CSV")
df_clean = pd.read_csv("./dataset/SOF PUF 2023 - Clean.csv")

# %%
df["RQ11_BASE"].value_counts()
# Out:
# RQ11_BASE
# 1    2975
#       729
# 2     597
# 3       3
# Name: count, dtype: int64

# %%
df_clean["Base"].value_counts()
# Out:
# Base
# Land-based    2975
# Sea-based      597
# Others           3
# Name: count, dtype: int64

# %%
df[(df['RQ15_2DGT'].str.strip() == "") & (df["RQ10_REASON"] == 2)][["RQ10_REASON",'RQ14_INDWORK', "RQ15_2DGT"]]
# Out:
#       RQ10_REASON  RQ14_INDWORK RQ15_2DGT
# 2511            2             2
